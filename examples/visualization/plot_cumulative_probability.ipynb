# %%
from tilepy.tools.PlotCumulativeCoverage import ObtainCumulativeProbabilityPlot, ObtainCumulativeProbabilityPlotLog

# %%
# Plot the cumulative probability of one of the examples
ObtainCumulativeProbabilityPlot('../sciencecases/P1500071/PGalinFoV_NObs/SuggestedPointings_GWOptimisation.txt','927563', 'Pgal',interactive=True)
ObtainCumulativeProbabilityPlot('../sciencecases/P1500071/PGalinFoV_NObs/SuggestedPointings_GWOptimisation.txt','927563', 'PGW',interactive=True)

# %%
# The log version, useful for follow-ups with small FoV
ObtainCumulativeProbabilityPlotLog('../sciencecases/S190814bv/PGalinFoV_NObs//SuggestedPointings_GWOptimisation.txt','S190814bv', 'PGW',interactive=False)
ObtainCumulativeProbabilityPlotLog('../sciencecases/S190814bv/PGalinFoV_NObs//SuggestedPointings_GWOptimisation.txt','S190814bv', 'Pgal',interactive=False)
