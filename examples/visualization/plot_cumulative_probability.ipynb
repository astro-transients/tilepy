# %%
from tilepy.tools.PlotCumulativeCoverage import ObtainCumulativeProbabilityPlot, ObtainCumulativeProbabilityPlotLog

# %%
# Plot the result of one of the examples
ObtainCumulativeProbabilityPlot('../obsLauncher/output/P1500071/PGalinFoV_NObs/SuggestedPointings_GWOptimisation.txt','927563', 'PGW',interactive=True)

# %%
# The log version, useful for follow-ups with small FoV
ObtainCumulativeProbabilityPlotLog('../obsLauncher/output/S190814bv/PGalinFoV_NObs//SuggestedPointings_GWOptimisation.txt','S190814bv', 'PGW',interactive=True)
