# %%
from tilepy.tools.PlotCumulativeCoverage import ObtainCumulativeProbabilityPlot, ObtainCumulativeProbabilityPlotLog

# %%
# Plot the result of one of the examples
ObtainCumulativeProbabilityPlot('../obsCases/927563_lalinference_PAPER/PGalinFoV_NObs/SuggestedPointings_GWOptimisation.txt','927563', 'PGW',interactive=True)

# %%
# The log version, useful for follow-ups with small FoV
ObtainCumulativeProbabilityPlotLog('../obsCases/S190814bv_PAPER/PGalinFoV_NObs/SuggestedPointings_GWOptimisation.txt','S190814bv', 'PGW',interactive=True)
